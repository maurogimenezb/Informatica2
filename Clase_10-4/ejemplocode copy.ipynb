# %%
import osmnx as ox
import random
import heapq

# %%
place_name = "Iturbe, Paraguay"
G = ox.graph_from_place(place_name, network_type="drive")

# %%
for edge in G.edges:
    # Cleaning the "maxspeed" attribute, some values are lists, some are strings, some are None
    maxspeed = 40
    if "maxspeed" in G.edges[edge]:
        maxspeed = G.edges[edge]["maxspeed"]
        if type(maxspeed) == list:
            speeds = [ int(speed) for speed in maxspeed ]
            maxspeed = min(speeds)
        elif type(maxspeed) == str:
            maxspeed = int(maxspeed)
    G.edges[edge]["maxspeed"] = maxspeed
    # Adding the "weight" attribute (time = distance / speed)
    G.edges[edge]["weight"] = G.edges[edge]["length"] / maxspeed

# %%
def style_unvisited_edge(edge):        
    G.edges[edge]["color"] = "#d36206"
    G.edges[edge]["alpha"] = 0.2
    G.edges[edge]["linewidth"] = 0.5

def style_visited_edge(edge):
    G.edges[edge]["color"] = "#d36206"
    G.edges[edge]["alpha"] = 1
    G.edges[edge]["linewidth"] = 1

def style_active_edge(edge):
    G.edges[edge]["color"] = '#e8a900'
    G.edges[edge]["alpha"] = 1
    G.edges[edge]["linewidth"] = 1

def style_path_edge(edge):
    G.edges[edge]["color"] = "white"
    G.edges[edge]["alpha"] = 1
    G.edges[edge]["linewidth"] = 1

# %%
def plot_graph():
    ox.plot_graph(
        G,
        node_size =  [ G.nodes[node]["size"] for node in G.nodes ],
        edge_color = [ G.edges[edge]["color"] for edge in G.edges ],
        edge_alpha = [ G.edges[edge]["alpha"] for edge in G.edges ],
        edge_linewidth = [ G.edges[edge]["linewidth"] for edge in G.edges ],
        node_color = "white",
        bgcolor = "#18080e"
    )

# %%
def plot_heatmap(algorithm):
    edge_colors = ox.plot.get_edge_colors_by_attr(G, f"{algorithm}_uses", cmap="hot")
    fig, _ = ox.plot_graph(
        G,
        node_size = 0,
        edge_color = edge_colors,
        bgcolor = "#18080e"
    )

# %%
def dijkstra(orig, dest, plot=False):
    for node in G.nodes:
        G.nodes[node]["visited"] = False
        G.nodes[node]["distance"] = float("inf")
        G.nodes[node]["previous"] = None
        G.nodes[node]["size"] = 0
    for edge in G.edges:
        style_unvisited_edge(edge)
    G.nodes[orig]["distance"] = 0
    G.nodes[orig]["size"] = 50
    G.nodes[dest]["size"] = 50
    pq = [(0, orig)]
    step = 0
    while pq:
        _, node = heapq.heappop(pq)
        if node == dest:
            if plot:
                print("Iteraciones:", step)
                plot_graph()
            return
        if G.nodes[node]["visited"]: continue
        G.nodes[node]["visited"] = True
        for edge in G.out_edges(node):
            style_visited_edge((edge[0], edge[1], 0))
            neighbor = edge[1]
            weight = G.edges[(edge[0], edge[1], 0)]["weight"]
            if G.nodes[neighbor]["distance"] > G.nodes[node]["distance"] + weight:
                G.nodes[neighbor]["distance"] = G.nodes[node]["distance"] + weight
                G.nodes[neighbor]["previous"] = node
                heapq.heappush(pq, (G.nodes[neighbor]["distance"], neighbor))
                for edge2 in G.out_edges(neighbor):
                    style_active_edge((edge2[0], edge2[1], 0))
        step += 1

# %%
def distance(node1, node2):
    x1, y1 = G.nodes[node1]["x"], G.nodes[node1]["y"]
    x2, y2 = G.nodes[node2]["x"], G.nodes[node2]["y"]
    return ((x2 - x1)**2 + (y2 - y1)**2)**0.5

def a_star(orig, dest, plot=False):
    for node in G.nodes:
        G.nodes[node]["previous"] = None
        G.nodes[node]["size"] = 0
        G.nodes[node]["g_score"] = float("inf")
        G.nodes[node]["f_score"] = float("inf")
    for edge in G.edges:
        style_unvisited_edge(edge)
    G.nodes[orig]["size"] = 50
    G.nodes[dest]["size"] = 50
    G.nodes[orig]["g_score"] = 0
    G.nodes[orig]["f_score"] = distance(orig, dest)
    pq = [(G.nodes[orig]["f_score"], orig)]
    step = 0
    while pq:
        _, node = heapq.heappop(pq)
        if node == dest:
            if plot:
                print("Iteraciones:", step)
                plot_graph()
            return
        for edge in G.out_edges(node):
            style_visited_edge((edge[0], edge[1], 0))
            neighbor = edge[1]
            tentative_g_score = G.nodes[node]["g_score"] + distance(node, neighbor)
            if tentative_g_score < G.nodes[neighbor]["g_score"]:
                G.nodes[neighbor]["previous"] = node
                G.nodes[neighbor]["g_score"] = tentative_g_score
                G.nodes[neighbor]["f_score"] = tentative_g_score + distance(neighbor, dest)
                heapq.heappush(pq, (G.nodes[neighbor]["f_score"], neighbor))
                for edge2 in G.out_edges(neighbor):
                    style_active_edge((edge2[0], edge2[1], 0))
        step += 1

# %%
def reconstruct_path(orig, dest, plot=False, algorithm=None):
    for edge in G.edges:
        style_unvisited_edge(edge)
    dist = 0
    speeds = []
    curr = dest
    while curr != orig:
        prev = G.nodes[curr]["previous"]
        dist += G.edges[(prev, curr, 0)]["length"]
        speeds.append(G.edges[(prev, curr, 0)]["maxspeed"])
        style_path_edge((prev, curr, 0))
        if algorithm:
            G.edges[(prev, curr, 0)][f"{algorithm}_uses"] = G.edges[(prev, curr, 0)].get(f"{algorithm}_uses", 0) + 1
        curr = prev
    dist /= 1000
    if plot:
        print(f"Distance: {dist}")
        print(f"Avg. speed: {sum(speeds)/len(speeds)}")
        print(f"Total time: {dist/(sum(speeds)/len(speeds)) * 60}")
        plot_graph()

# %%
start = random.choice(list(G.nodes))
end = random.choice(list(G.nodes))
print(f"ID del nodo random: {start}")
print(f"ID del nodo random: {end}")
# Out:
# ID del nodo random: 2639492594
# ID del nodo random: 2639535885

# %%
dijkstra(start, end, plot=True)
# Out:
# Iteraciones: 142

# %% [markdown]
# # Experiment 2

# %%
N = 100 # times to run each algorithm
for edge in G.edges:
    G.edges[edge]["dijkstra_uses"] = 0
    G.edges[edge]["a_star_uses"] = 0

# %%
for _ in range(N): # (might take a while, depending on N)
    start = random.choice(list(G.nodes))
    end = random.choice(list(G.nodes))
    dijkstra(start, end)
    reconstruct_path(start, end, algorithm="dijkstra")
    a_star(start, end)
    reconstruct_path(start, end, algorithm="a_star")
    print(f"ID del nodo más cercano a la Plaza de Mayo: {start}")
# Out:
# ID del nodo más cercano a la Plaza de Mayo: 2639534736
# ID del nodo más cercano a la Plaza de Mayo: 2639492697
# ID del nodo más cercano a la Plaza de Mayo: 2639535888
# ID del nodo más cercano a la Plaza de Mayo: 2639538120
# ID del nodo más cercano a la Plaza de Mayo: 2639543057
# ID del nodo más cercano a la Plaza de Mayo: 2639537531
# ID del nodo más cercano a la Plaza de Mayo: 2408271344
# ID del nodo más cercano a la Plaza de Mayo: 2639538111
# ID del nodo más cercano a la Plaza de Mayo: 2639535867
# ID del nodo más cercano a la Plaza de Mayo: 2639538264
# ID del nodo más cercano a la Plaza de Mayo: 2639535884
# ID del nodo más cercano a la Plaza de Mayo: 2639538264
# ID del nodo más cercano a la Plaza de Mayo: 2639535897
# ID del nodo más cercano a la Plaza de Mayo: 2639534737
# ID del nodo más cercano a la Plaza de Mayo: 2639538125
# ID del nodo más cercano a la Plaza de Mayo: 2639538120
# ID del nodo más cercano a la Plaza de Mayo: 2639523979
# ID del nodo más cercano a la Plaza de Mayo: 2639535887
# ID del nodo más cercano a la Plaza de Mayo: 2639526163
# ID del nodo más cercano a la Plaza de Mayo: 2639537534
# ID del nodo más cercano a la Plaza de Mayo: 2639538264
# ID del nodo más cercano a la Plaza de Mayo: 2639535894
# ID del nodo más cercano a la Plaza de Mayo: 2639523974
# ID del nodo más cercano a la Plaza de Mayo: 2639538264
# ID del nodo más cercano a la Plaza de Mayo: 2639537523
# ID del nodo más cercano a la Plaza de Mayo: 2639527822
# ID del nodo más cercano a la Plaza de Mayo: 7975389816
# ID del nodo más cercano a la Plaza de Mayo: 2639526147
# ID del nodo más cercano a la Plaza de Mayo: 2639492490
# ID del nodo más cercano a la Plaza de Mayo: 2639538800
# ID del nodo más cercano a la Plaza de Mayo: 2639526149
# ID del nodo más cercano a la Plaza de Mayo: 2639538267
# ID del nodo más cercano a la Plaza de Mayo: 2639537531
# ID del nodo más cercano a la Plaza de Mayo: 7170374899
# ID del nodo más cercano a la Plaza de Mayo: 2639524606
# ID del nodo más cercano a la Plaza de Mayo: 2639492634
# ID del nodo más cercano a la Plaza de Mayo: 2639534733
# ID del nodo más cercano a la Plaza de Mayo: 2639535885
# ID del nodo más cercano a la Plaza de Mayo: 2639499542
# ID del nodo más cercano a la Plaza de Mayo: 2639492697
# ID del nodo más cercano a la Plaza de Mayo: 2639524612
# ID del nodo más cercano a la Plaza de Mayo: 2639538111
# ID del nodo más cercano a la Plaza de Mayo: 2639526145
# ID del nodo más cercano a la Plaza de Mayo: 2639537540
# ID del nodo más cercano a la Plaza de Mayo: 2639537532
# ID del nodo más cercano a la Plaza de Mayo: 7975389815
# ID del nodo más cercano a la Plaza de Mayo: 2639526151
# ID del nodo más cercano a la Plaza de Mayo: 2639537534
# ID del nodo más cercano a la Plaza de Mayo: 2639492680
# ID del nodo más cercano a la Plaza de Mayo: 4976833430
# ID del nodo más cercano a la Plaza de Mayo: 2639535867
# ID del nodo más cercano a la Plaza de Mayo: 2408271341
# ID del nodo más cercano a la Plaza de Mayo: 2639524608
# ID del nodo más cercano a la Plaza de Mayo: 2639526149
# ID del nodo más cercano a la Plaza de Mayo: 2639535862
# ID del nodo más cercano a la Plaza de Mayo: 2639538121
# ID del nodo más cercano a la Plaza de Mayo: 2639537536
# ID del nodo más cercano a la Plaza de Mayo: 2639535866
# ID del nodo más cercano a la Plaza de Mayo: 2639523959
# ID del nodo más cercano a la Plaza de Mayo: 2639535887
# ID del nodo más cercano a la Plaza de Mayo: 2639537528
# ID del nodo más cercano a la Plaza de Mayo: 2639534730
# ID del nodo más cercano a la Plaza de Mayo: 2639538116
# ID del nodo más cercano a la Plaza de Mayo: 2639492865
# ID del nodo más cercano a la Plaza de Mayo: 2639535891
# ID del nodo más cercano a la Plaza de Mayo: 2639526148
# ID del nodo más cercano a la Plaza de Mayo: 2639534739
# ID del nodo más cercano a la Plaza de Mayo: 2639534737
# ID del nodo más cercano a la Plaza de Mayo: 2639526142
# ID del nodo más cercano a la Plaza de Mayo: 4976833430
# ID del nodo más cercano a la Plaza de Mayo: 2639540313
# ID del nodo más cercano a la Plaza de Mayo: 2639514080
# ID del nodo más cercano a la Plaza de Mayo: 6743219522
# ID del nodo más cercano a la Plaza de Mayo: 7975389815
# ID del nodo más cercano a la Plaza de Mayo: 4008798538
# ID del nodo más cercano a la Plaza de Mayo: 2639514078
# ID del nodo más cercano a la Plaza de Mayo: 2639526164
# ID del nodo más cercano a la Plaza de Mayo: 7170374899
# ID del nodo más cercano a la Plaza de Mayo: 2639538263
# ID del nodo más cercano a la Plaza de Mayo: 2639523982
# ID del nodo más cercano a la Plaza de Mayo: 2639523974
# ID del nodo más cercano a la Plaza de Mayo: 2639535879
# ID del nodo más cercano a la Plaza de Mayo: 2639535864
# ID del nodo más cercano a la Plaza de Mayo: 2639523963
# ID del nodo más cercano a la Plaza de Mayo: 2639523949
# ID del nodo más cercano a la Plaza de Mayo: 2639535862
# ID del nodo más cercano a la Plaza de Mayo: 2639535887
# ID del nodo más cercano a la Plaza de Mayo: 2639526149
# ID del nodo más cercano a la Plaza de Mayo: 2639535887
# ID del nodo más cercano a la Plaza de Mayo: 2639543057
# ID del nodo más cercano a la Plaza de Mayo: 2639538263
# ID del nodo más cercano a la Plaza de Mayo: 2639535868
# ID del nodo más cercano a la Plaza de Mayo: 2639535880
# ID del nodo más cercano a la Plaza de Mayo: 2639534737
# ID del nodo más cercano a la Plaza de Mayo: 2639537523
# ID del nodo más cercano a la Plaza de Mayo: 2639538115
# ID del nodo más cercano a la Plaza de Mayo: 2408271344
# ID del nodo más cercano a la Plaza de Mayo: 2639537543
# ID del nodo más cercano a la Plaza de Mayo: 2639537544
# ID del nodo más cercano a la Plaza de Mayo: 2639538264

# %%
plot_heatmap("dijkstra")

# %%
plot_heatmap("a_star")

# %%
a_star(start, end, plot=True)
# Out:
# Iteraciones: 46

# %%
dijkstra(start, end, plot=True)
# Out:
# Iteraciones: 40

# %%
a_star(start, end, plot=True)
# Out:
# Iteraciones: 14

# %%
a_star(start, end, plot=True)
# Out:
# Iteraciones: 14

# %%
a_star(start, end, plot=True)
# Out:
# Iteraciones: 14
